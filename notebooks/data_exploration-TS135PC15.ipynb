# %%
import sys
sys.path.append('..')
import torch
import torch.backends.cudnn as cudnn
import torchvision
import matplotlib.pyplot as plt

cudnn.benchmark = True
plt.ion()   # interactive mode

# %%
BATCH_SIZE=8
SHUFFLE=True
WORKERS=24

# %%
from src.data_loader import GetDataLoaders, imshow, GetDataLoadersEuroSat
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

data_dir = '..\\data\\miniImageNet'
dataloaders, class_names, dataset_sizes  = GetDataLoaders(data_dir, BATCH_SIZE, SHUFFLE, num_workers=WORKERS)

# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))
out = torchvision.utils.make_grid(inputs)
imshow(out, title=[class_names[x] for x in classes])

# %%
data_dir = '..\\data\\EuroSAT_RGB'
dataloaders, class_names, dataset_sizes  = GetDataLoadersEuroSat(data_dir, BATCH_SIZE, SHUFFLE, num_workers=WORKERS)

# %%
inputs, classes = next(iter(dataloaders['train']))
out = torchvision.utils.make_grid(inputs)
imshow(out, title=[class_names[x] for x in classes])
